# %%
import sys
import yfinance as yf
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
from bs4 import BeautifulSoup

# %%
def draw_line(name):
    ticker = yf.Ticker(name)
    df = ticker.history(interval='1mo', auto_adjust=False,
                        period='2y', start='2020-01-01')

    print(df.head())

    days = df.index.strftime('%Y-%m')
    plt.figure(figsize=(10, 6))
    plt.plot(days, df['Open'], marker='.', color='red')

    plt.title('Open Price of Samsung for 30 days')
    plt.xlabel('Date')
    plt.ylabel('Open Price')
    plt.ylim(10000, 100000)

    plt.grid(True)
    plt.show()

# %%
name = 'MSFT'
msft = yf.Ticker(name)
opt = msft.option_chain('2025-12-19')
opt.puts
# Out:
#          contractSymbol             lastTradeDate  strike  lastPrice     bid  \
# 0   MSFT251219P00125000 2024-04-24 15:27:38+00:00   125.0       0.46    0.20
# 1   MSFT251219P00130000 2024-01-30 16:08:20+00:00   130.0       0.60    0.03
# 2   MSFT251219P00135000 2024-04-22 13:39:25+00:00   135.0       0.54    0.02
# 3   MSFT251219P00140000 2024-04-19 18:27:46+00:00   140.0       0.80    0.02
# 4   MSFT251219P00145000 2024-04-22 13:39:25+00:00   145.0       0.89    0.50
# ..                  ...                       ...     ...        ...     ...
# 80  MSFT251219P00550000 2024-04-15 16:38:12+00:00   550.0     130.86  141.00
# 81  MSFT251219P00560000 2024-04-05 14:24:00+00:00   560.0     138.77  151.00
# 82  MSFT251219P00570000 2024-04-02 15:13:51+00:00   570.0     149.71  161.00
# 83  MSFT251219P00610000 2024-04-05 14:24:00+00:00   610.0     188.47  201.00
# 84  MSFT251219P00620000 2024-04-26 13:57:50+00:00   620.0     210.24  211.00
#
# ...
